# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read

# %%
ipl_data = pd.read_csv('IPL 2017 - Adv Report v1.csv')
ipl_data.head()
# Out:
#    Unnamed: 0   Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  \
# 0           0  Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM
# 1           1  Sony MAX  05/04/2017         06:35:02 PM       06:35:12 PM
# 2           2  Sony MAX  05/04/2017         06:35:12 PM       06:35:42 PM
# 3           3  Sony MAX  05/04/2017         06:35:42 PM       06:36:12 PM
# 4           4  Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM
#
#    Month  Length [sec] {Av}       Description    Ev. Type             Brand  \
# 0      4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
# 1      4                 10      YAMAHA FZ 25  Commercial      YAMAHA FZ 25
# 2      4                 30  JIO DIGITAL LIFE  Commercial  JIO DIGITAL LIFE
# 3      4                 30    AMUL ICE CREAM  Commercial    AMUL ICE CREAM
# 4      4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
#
#                                Sector                      Category  \
# 0                    Telecom Products  CELLULAR PHONES-SMART PHONES
# 1                                Auto             AUTO-TWO WHEELERS
# 2  Telecom/Internet Service Providers        CELLULAR PHONE SERVICE
# 3                    Food & Beverages     ICE CREAM/FROZEN DESSERTS
# 4                    Telecom Products  CELLULAR PHONES-SMART PHONES
#
#                       Advertiser Impressions´000 {Av(Wg)} Rate/10 Sec  \
# 0                     OPPO INDIA                 2,463.19    200,000
# 1     YAMAHA MOTOR INDIA PVT LTD                 2,006.82    200,000
# 2      RELIANCE JIO INFOCOMM LTD                 2,006.82    200,000
# 3  GCMMF (GUJ COOP MILK MKT FED)                 1,966.16    200,000
# 4                     OPPO INDIA                 1,905.15    200,000
#
#         Cost
# 0   300,000
# 1   200,000
# 2   600,000
# 3   600,000
# 4   300,000

# %%
ipl_data = ipl_data.iloc[:,1:]
ipl_data.head()
# Out:
#     Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 0  Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM      4
# 1  Sony MAX  05/04/2017         06:35:02 PM       06:35:12 PM      4
# 2  Sony MAX  05/04/2017         06:35:12 PM       06:35:42 PM      4
# 3  Sony MAX  05/04/2017         06:35:42 PM       06:36:12 PM      4
# 4  Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM      4
#
#    Length [sec] {Av}       Description    Ev. Type             Brand  \
# 0                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
# 1                 10      YAMAHA FZ 25  Commercial      YAMAHA FZ 25
# 2                 30  JIO DIGITAL LIFE  Commercial  JIO DIGITAL LIFE
# 3                 30    AMUL ICE CREAM  Commercial    AMUL ICE CREAM
# 4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
#
#                                Sector                      Category  \
# 0                    Telecom Products  CELLULAR PHONES-SMART PHONES
# 1                                Auto             AUTO-TWO WHEELERS
# 2  Telecom/Internet Service Providers        CELLULAR PHONE SERVICE
# 3                    Food & Beverages     ICE CREAM/FROZEN DESSERTS
# 4                    Telecom Products  CELLULAR PHONES-SMART PHONES
#
#                       Advertiser Impressions´000 {Av(Wg)} Rate/10 Sec  \
# 0                     OPPO INDIA                 2,463.19    200,000
# 1     YAMAHA MOTOR INDIA PVT LTD                 2,006.82    200,000
# 2      RELIANCE JIO INFOCOMM LTD                 2,006.82    200,000
# 3  GCMMF (GUJ COOP MILK MKT FED)                 1,966.16    200,000
# 4                     OPPO INDIA                 1,905.15    200,000
#
#         Cost
# 0   300,000
# 1   200,000
# 2   600,000
# 3   600,000
# 4   300,000

# %%
ipl_data.shape
# Out:
# (58924, 15)

# %% [markdown]
# ## NA?

# %%
ipl_data.isnull().any(axis=0)
# Out:
# Channel                     False
# Date                        False
# Start Time {Av(Tm)}         False
# End Time {Av(Tm)}           False
# Month                       False
# Length [sec] {Av}           False
# Description                 False
# Ev. Type                    False
# Brand                       False
# Sector                      False
# Category                    False
# Advertiser                  False
# Impressions´000 {Av(Wg)}    False
# Rate/10 Sec                 False
# Cost                         True
# dtype: bool

# %%
ipl_data.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 58894    False
# 58895    False
# 58896    False
# 58897    False
# 58898    False
# 58899    False
# 58900    False
# 58901    False
# 58902    False
# 58903    False
# 58904    False
# 58905    False
# 58906    False
# 58907    False
# 58908    False
# 58909    False
# 58910    False
# 58911    False
# 58912    False
# 58913    False
# 58914    False
# 58915    False
# 58916    False
# 58917    False
# 58918    False
# 58919    False
# 58920    False
# 58921    False
# 58922    False
# 58923    False
# Length: 58924, dtype: bool

# %%
ipl_data[ipl_data.isnull().any(axis=1)]
# Out:
#           Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 6634  Sony SIX HD  10/04/2017         10:26:42 PM       10:26:52 PM      4
#
#       Length [sec] {Av}          Description    Ev. Type                Brand  \
# 6634                 10  AMITY UNIVERSITY-OT  Commercial  AMITY UNIVERSITY-OT
#
#          Sector            Category             Advertiser  \
# 6634  Education  EDUC-OTHER COURSES  AMITY EDUCATION GROUP
#
#       Impressions´000 {Av(Wg)}  Rate/10 Sec  Cost
# 6634                    238.14       200000   NaN

# %% [markdown]
# ## Replace

# %%
ipl_data['Cost'] = ipl_data['Cost'].str.replace(',',"")
ipl_data.head()
# Out:
#     Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 0  Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM      4
# 1  Sony MAX  05/04/2017         06:35:02 PM       06:35:12 PM      4
# 2  Sony MAX  05/04/2017         06:35:12 PM       06:35:42 PM      4
# 3  Sony MAX  05/04/2017         06:35:42 PM       06:36:12 PM      4
# 4  Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM      4
#
#    Length [sec] {Av}       Description    Ev. Type             Brand  \
# 0                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
# 1                 10      YAMAHA FZ 25  Commercial      YAMAHA FZ 25
# 2                 30  JIO DIGITAL LIFE  Commercial  JIO DIGITAL LIFE
# 3                 30    AMUL ICE CREAM  Commercial    AMUL ICE CREAM
# 4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
#
#                                Sector                      Category  \
# 0                    Telecom Products  CELLULAR PHONES-SMART PHONES
# 1                                Auto             AUTO-TWO WHEELERS
# 2  Telecom/Internet Service Providers        CELLULAR PHONE SERVICE
# 3                    Food & Beverages     ICE CREAM/FROZEN DESSERTS
# 4                    Telecom Products  CELLULAR PHONES-SMART PHONES
#
#                       Advertiser Impressions´000 {Av(Wg)} Rate/10 Sec  \
# 0                     OPPO INDIA                 2,463.19    200,000
# 1     YAMAHA MOTOR INDIA PVT LTD                 2,006.82    200,000
# 2      RELIANCE JIO INFOCOMM LTD                 2,006.82    200,000
# 3  GCMMF (GUJ COOP MILK MKT FED)                 1,966.16    200,000
# 4                     OPPO INDIA                 1,905.15    200,000
#
#        Cost
# 0   300000
# 1   200000
# 2   600000
# 3   600000
# 4   300000

# %%
ipl_data["Impressions´000 {Av(Wg)}"] = ipl_data["Impressions´000 {Av(Wg)}"].str.replace(',',"")
ipl_data['Rate/10 Sec'] = ipl_data['Rate/10 Sec'].str.replace(',',"")
ipl_data["Impressions´000 {Av(Wg)}"] = ipl_data["Impressions´000 {Av(Wg)}"].astype('float64')
ipl_data['Rate/10 Sec'] = ipl_data['Rate/10 Sec'].astype(int)
ipl_data.head()
# Out:
#     Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 0  Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM      4
# 1  Sony MAX  05/04/2017         06:35:02 PM       06:35:12 PM      4
# 2  Sony MAX  05/04/2017         06:35:12 PM       06:35:42 PM      4
# 3  Sony MAX  05/04/2017         06:35:42 PM       06:36:12 PM      4
# 4  Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM      4
#
#    Length [sec] {Av}       Description    Ev. Type             Brand  \
# 0                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
# 1                 10      YAMAHA FZ 25  Commercial      YAMAHA FZ 25
# 2                 30  JIO DIGITAL LIFE  Commercial  JIO DIGITAL LIFE
# 3                 30    AMUL ICE CREAM  Commercial    AMUL ICE CREAM
# 4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
#
#                                Sector                      Category  \
# 0                    Telecom Products  CELLULAR PHONES-SMART PHONES
# 1                                Auto             AUTO-TWO WHEELERS
# 2  Telecom/Internet Service Providers        CELLULAR PHONE SERVICE
# 3                    Food & Beverages     ICE CREAM/FROZEN DESSERTS
# 4                    Telecom Products  CELLULAR PHONES-SMART PHONES
#
#                       Advertiser  Impressions´000 {Av(Wg)}  Rate/10 Sec  \
# 0                     OPPO INDIA                   2463.19       200000
# 1     YAMAHA MOTOR INDIA PVT LTD                   2006.82       200000
# 2      RELIANCE JIO INFOCOMM LTD                   2006.82       200000
# 3  GCMMF (GUJ COOP MILK MKT FED)                   1966.16       200000
# 4                     OPPO INDIA                   1905.15       200000
#
#        Cost
# 0   300000
# 1   200000
# 2   600000
# 3   600000
# 4   300000

# %% [markdown]
# ## NaN

# %%
ipl_data['Cost'] = ipl_data['Cost'].astype(float) # not int

# %%
ipl_data["Cost"][ipl_data["Advertiser"] == "AMITY EDUCATION GROUP"].mean()
# Out:
# 200000.0

# %%
ipl_data["Cost"] = ipl_data["Cost"].fillna(ipl_data["Cost"][ipl_data["Advertiser"] == "AMITY EDUCATION GROUP"].mean())
ipl_data.iloc[6634,:]
# Out:
# Channel                               Sony SIX HD
# Date                                   10/04/2017
# Start Time {Av(Tm)}                   10:26:42 PM
# End Time {Av(Tm)}                     10:26:52 PM
# Month                                           4
# Length [sec] {Av}                              10
# Description                   AMITY UNIVERSITY-OT
# Ev. Type                               Commercial
# Brand                         AMITY UNIVERSITY-OT
# Sector                                  Education
# Category                       EDUC-OTHER COURSES
# Advertiser                  AMITY EDUCATION GROUP
# Impressions´000 {Av(Wg)}                   238.14
# Rate/10 Sec                                200000
# Cost                                       200000
# Name: 6634, dtype: object

# %%
ipl_data['Cost'] = ipl_data['Cost'].astype(int)

# %% [markdown]
# ## Change column names

# %%
names=ipl_data.columns.tolist()
names[names.index('Impressions´000 {Av(Wg)}')]='Impressions'
ipl_data.columns=names
ipl_data.head()
# Out:
#     Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 0  Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM      4
# 1  Sony MAX  05/04/2017         06:35:02 PM       06:35:12 PM      4
# 2  Sony MAX  05/04/2017         06:35:12 PM       06:35:42 PM      4
# 3  Sony MAX  05/04/2017         06:35:42 PM       06:36:12 PM      4
# 4  Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM      4
#
#    Length [sec] {Av}       Description    Ev. Type             Brand  \
# 0                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
# 1                 10      YAMAHA FZ 25  Commercial      YAMAHA FZ 25
# 2                 30  JIO DIGITAL LIFE  Commercial  JIO DIGITAL LIFE
# 3                 30    AMUL ICE CREAM  Commercial    AMUL ICE CREAM
# 4                 15      OPPO F3 PLUS  Commercial      OPPO F3 PLUS
#
#                                Sector                      Category  \
# 0                    Telecom Products  CELLULAR PHONES-SMART PHONES
# 1                                Auto             AUTO-TWO WHEELERS
# 2  Telecom/Internet Service Providers        CELLULAR PHONE SERVICE
# 3                    Food & Beverages     ICE CREAM/FROZEN DESSERTS
# 4                    Telecom Products  CELLULAR PHONES-SMART PHONES
#
#                       Advertiser  Impressions  Rate/10 Sec    Cost
# 0                     OPPO INDIA      2463.19       200000  300000
# 1     YAMAHA MOTOR INDIA PVT LTD      2006.82       200000  200000
# 2      RELIANCE JIO INFOCOMM LTD      2006.82       200000  600000
# 3  GCMMF (GUJ COOP MILK MKT FED)      1966.16       200000  600000
# 4                     OPPO INDIA      1905.15       200000  300000

# %% [markdown]
# ## Group-by Channel

# %%
Channel_data=ipl_data.groupby("Channel").Impressions.mean()
Channel_data
# Out:
# Channel
# Sony MAX       6831.787749
# Sony SIX HD      79.919189
# Sony SIX(v)    2355.721386
# Name: Impressions, dtype: float64

# %%
labels='Sony Max','Sony Six HD','Sony Six (V)'
explode=(0.2,0.4,0.1)
plt.pie(Channel_data, labels=labels, explode=explode , shadow=True, startangle=90)
plt.title('Channel-wise Impressions', bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %% [markdown]
# ## Group-by Sector

# %%
ipl_grp_sector = ipl_data.groupby("Sector")
ipl_grp_sector["Sector"].count().sort_values(ascending = False)
# Out:
# Sector
# Durables                                            12046
# Telecom Products                                     8967
# Food & Beverages                                     6798
# Auto                                                 6331
# Personal Care/Personal Hygiene                       4503
# Textiles/Clothing                                    4438
# Telecom/Internet Service Providers                   4249
# Services                                             3498
# Building, Industrial & Land Materials/Equipments     1972
# Alcoholic Drinks                                     1247
# Corporate/Brand Image                                1237
# Retail                                                700
# Banking/Finance/Investment                            637
# Fuel/Petroleum Products                               554
# Personal Healthcare                                   507
# Miscellaneous                                         405
# Personal Accessories                                  370
# Laundry                                               297
# Hair Care                                              88
# Education                                              75
# Cosmetics                                               5
# Name: Sector, dtype: int64

# %%
ipl_grp_month = ipl_data.groupby("Month")
ipl_grp_month["Month"].count().sort_values(ascending = False)
# Out:
# Month
# 4    33208
# 5    25716
# Name: Month, dtype: int64

# %% [markdown]
# ## Sector to Impressions

# %%
sectorwise_data=ipl_data.groupby('Sector').Impressions.mean().sort_values()
sectorwise_data
# Out:
# Sector
# Retail                                               189.798114
# Education                                            412.583067
# Cosmetics                                            472.266000
# Miscellaneous                                        531.768469
# Personal Healthcare                                  636.194911
# Hair Care                                            728.616023
# Laundry                                             1000.428687
# Corporate/Brand Image                               1273.590445
# Personal Care/Personal Hygiene                      1292.736245
# Alcoholic Drinks                                    1326.013103
# Fuel/Petroleum Products                             2541.463430
# Durables                                            2627.378888
# Banking/Finance/Investment                          2729.126342
# Textiles/Clothing                                   2756.636138
# Services                                            3311.934345
# Telecom/Internet Service Providers                  3341.628117
# Food & Beverages                                    3368.243713
# Building, Industrial & Land Materials/Equipments    4103.338717
# Auto                                                4237.403729
# Telecom Products                                    4552.294885
# Personal Accessories                                5799.495676
# Name: Impressions, dtype: float64

# %%
plt.figure(figsize = (15,8))
sectorwise_data.plot(kind = "bar")

# %% [markdown]
# ## Brand to Impression

# %%
brandwise_data=ipl_data.groupby('Brand').Impressions.mean()
brandwise_data.sort_values(ascending=False).head().sort_values().plot(kind = "barh")

# %% [markdown]
# ## Advertisement Count

# %%
ipl_data.groupby('Brand').Advertiser.count().sort_values(ascending = False).head(10).sort_values().plot(kind = "barh")

# %%
ipl_data['Start Time {Av(Tm)}']=pd.to_datetime(ipl_data['Start Time {Av(Tm)}'])
ipl_data['hour']=ipl_data['Start Time {Av(Tm)}'].dt.hour
hourwise_data=ipl_data.groupby('hour').Impressions.mean()

# %%
plt.figure(figsize = (10,8))
plt.plot(hourwise_data)
plt.ylabel(' Average Impressions')
plt.xlabel('Hour of the Day in 24 Hr Format')
# Out:
# Text(0.5,0,'Hour of the Day in 24 Hr Format')

# %% [markdown]
# ## Company Spends

# %%
impressions_by_sector_across_channels_table = pd.pivot_table(ipl_data, values='Impressions', index=['Channel'],columns=['Sector'], aggfunc=np.median)
round(impressions_by_sector_across_channels_table,2)
# Out:
# Sector       Alcoholic Drinks     Auto  Banking/Finance/Investment  \
# Channel
# Sony MAX             12365.04  7922.46                    12288.97
# Sony SIX HD              4.67    84.76                      118.97
# Sony SIX(v)            452.90  3268.94                     2855.80
#
# Sector       Building, Industrial & Land Materials/Equipments  \
# Channel
# Sony MAX                                             12884.50
# Sony SIX HD                                             71.67
# Sony SIX(v)                                           2708.86
#
# Sector       Corporate/Brand Image  Cosmetics  Durables  Education  \
# Channel
# Sony MAX                    836.41     530.94   2213.59    1095.94
# Sony SIX HD                  17.73        NaN     69.64     106.27
# Sony SIX(v)                 528.93        NaN   1524.13     493.81
#
# Sector       Food & Beverages  Fuel/Petroleum Products        ...          \
# Channel                                                       ...
# Sony MAX              2275.60                 11535.20        ...
# Sony SIX HD             41.15                     1.74        ...
# Sony SIX(v)           2354.20                   559.94        ...
#
# Sector       Laundry  Miscellaneous  Personal Accessories  \
# Channel
# Sony MAX     1788.81        2913.49              11136.01
# Sony SIX HD    26.49          13.62                  9.83
# Sony SIX(v)   602.92         369.03               3058.71
#
# Sector       Personal Care/Personal Hygiene  Personal Healthcare  Retail  \
# Channel
# Sony MAX                            1714.39              1111.08  563.35
# Sony SIX HD                           15.56                22.33  134.64
# Sony SIX(v)                          455.79               366.02  551.09
#
# Sector       Services  Telecom Products  Telecom/Internet Service Providers  \
# Channel
# Sony MAX      5723.58          10184.82                             2348.78
# Sony SIX HD    104.17            100.88                               91.30
# Sony SIX(v)   3003.13           3480.19                             2860.73
#
# Sector       Textiles/Clothing
# Channel
# Sony MAX               5026.01
# Sony SIX HD              18.36
# Sony SIX(v)             712.42
#
# [3 rows x 21 columns]

# %%
ipl_tel_grp_p = impressions_by_sector_across_channels_table[["Alcoholic Drinks","Banking/Finance/Investment","Telecom/Internet Service Providers","Food & Beverages","Auto"]].plot(title = 'Sector-Wise Impressions Across Channel', kind = "bar")
ipl_tel_grp_p = ipl_tel_grp_p.get_figure()
ipl_tel_grp_p.set_size_inches(22, 12)

# %% [markdown]
# ## Telecom Sector

# %%
ipl_tel = ipl_data[(ipl_data['Sector'] == 'Telecom Products')]
ipl_tel
# Out:
#            Channel        Date Start Time {Av(Tm)} End Time {Av(Tm)}  Month  \
# 0         Sony MAX  05/04/2017         06:34:47 PM       06:35:02 PM      4
# 4         Sony MAX  05/04/2017         06:36:12 PM       06:36:27 PM      4
# 168                   30          VIVO SMART PHONES  Commercial
# 177                   15               OPPO F3 PLUS  Commercial
# 180                   30                    VIVO V5  Commercial
# 185                   15               OPPO F3 PLUS  Commercial
# ...                  ...                        ...         ...
# 58719                 15            OPPO F3/F3 PLUS  Commercial
# 58725                 20          VIVO V5 S/V5 PLUS  Commercial
# 58730                 15            OPPO F3/F3 PLUS  Commercial
# 58734                 20          VIVO V5 S/V5 PLUS  Commercial
# 58753                 20          VIVO V5 S/V5 PLUS  Commercial
# 58758                 15            OPPO F3/F3 PLUS  Commercial
# 58762                 15                  GIONEE A1  Commercial
# 58764                 15            OPPO F3/F3 PLUS  Commercial
# 58766                 20          VIVO V5 S/V5 PLUS  Commercial
# 58770                 15            OPPO F3/F3 PLUS  Commercial
# 58778                 20          VIVO V5 S/V5 PLUS  Commercial
# 58781                 30                     JIO FI  Commercial
# 58782                 15            OPPO F3/F3 PLUS  Commercial
# 58784                 15                  GIONEE A1  Commercial
# 58788                 20          VIVO V5 S/V5 PLUS  Commercial
# 58797                 10  SAMSUNG GALAXY S8/S8 PLUS  Commercial
# 58801                 15            OPPO F3/F3 PLUS  Commercial
# 58803                 15            OPPO F3/F3 PLUS  Commercial
# 58810                 20  SAMSUNG GALAXY S8/S8 PLUS  Commercial
# 58820                 30                     JIO FI  Commercial
# 58824                 20          VIVO V5 S/V5 PLUS  Commercial
# 58826                 15            OPPO F3/F3 PLUS  Commercial
# 58832                 15                  GIONEE A1  Commercial
# 58836                 15            OPPO F3/F3 PLUS  Commercial
# 58843                 15                  GIONEE A1  Commercial
# 58849                 15                  GIONEE A1  Commercial
# 58862                 20            MICROMAX DUAL 5  Commercial
# 58869                 45                   VIVO CAM  Commercial
# 58909                 20          VIVO V5 S/V5 PLUS  Commercial
# 58919                 20          VIVO V5 S/V5 PLUS  Commercial
#
#                            Brand            Sector  \
# 0                   OPPO F3 PLUS  Telecom Products
# 4                   OPPO F3 PLUS  Telecom Products
# 7         MOTOROLA MOTO G FAMILY  Telecom Products
# 9                    SAMSUNG PAY  Telecom Products
# 12        MOTOROLA MOTO G FAMILY  Telecom Products
# 15                  OPPO F3 PLUS  Telecom Products
# 19                  OPPO F3 PLUS  Telecom Products
# 21                  OPPO F3 PLUS  Telecom Products
# 24                   SAMSUNG PAY  Telecom Products
# 28                  OPPO F3 PLUS  Telecom Products
# 60                       VIVO V5  Telecom Products
# 71                       VIVO V5  Telecom Products
# 75                       VIVO V5  Telecom Products
# 93                  OPPO F3 PLUS  Telecom Products
# 107                      VIVO V5  Telecom Products
# 113                 OPPO F3 PLUS  Telecom Products
# 118                      VIVO V5  Telecom Products
# 122                 OPPO F3 PLUS  Telecom Products
# 124                      VIVO V5  Telecom Products
# 127                 OPPO F3 PLUS  Telecom Products
# 128                      VIVO V5  Telecom Products
# 132                      VIVO V5  Telecom Products
# 138                 OPPO F3 PLUS  Telecom Products
# 143                 OPPO F3 PLUS  Telecom Products
# 144            VIVO SMART PHONES  Telecom Products
# 150                 OPPO F3 PLUS  Telecom Products
# 168            VIVO SMART PHONES  Telecom Products
# 177                 OPPO F3 PLUS  Telecom Products
# 180                      VIVO V5  Telecom Products
# 185                 OPPO F3 PLUS  Telecom Products
# ...                          ...               ...
# 58719            OPPO F3/F3 PLUS  Telecom Products
# 58725          VIVO V5 S/V5 PLUS  Telecom Products
# 58730            OPPO F3/F3 PLUS  Telecom Products
# 58734          VIVO V5 S/V5 PLUS  Telecom Products
# 58753          VIVO V5 S/V5 PLUS  Telecom Products
# 58758            OPPO F3/F3 PLUS  Telecom Products
# 58762                  GIONEE A1  Telecom Products
# 58764            OPPO F3/F3 PLUS  Telecom Products
# 58766          VIVO V5 S/V5 PLUS  Telecom Products
# 58770            OPPO F3/F3 PLUS  Telecom Products
# 58778          VIVO V5 S/V5 PLUS  Telecom Products
# 58781                     JIO FI  Telecom Products
# 58782            OPPO F3/F3 PLUS  Telecom Products
# 58784                  GIONEE A1  Telecom Products
# 58788          VIVO V5 S/V5 PLUS  Telecom Products
# 58797  SAMSUNG GALAXY S8/S8 PLUS  Telecom Products
# 58801            OPPO F3/F3 PLUS  Telecom Products
# 58803            OPPO F3/F3 PLUS  Telecom Products
# 58810  SAMSUNG GALAXY S8/S8 PLUS  Telecom Products
# 58820                     JIO FI  Telecom Products
# 58824          VIVO V5 S/V5 PLUS  Telecom Products
# 58826            OPPO F3/F3 PLUS  Telecom Products
# 58832                  GIONEE A1  Telecom Products
# 58836            OPPO F3/F3 PLUS  Telecom Products
# 58843                  GIONEE A1  Telecom Products
# 58849                  GIONEE A1  Telecom Products
# 58862            MICROMAX DUAL 5  Telecom Products
# 58869                   VIVO CAM  Telecom Products
# 58909          VIVO V5 S/V5 PLUS  Telecom Products
# 58919          VIVO V5 S/V5 PLUS  Telecom Products
#
#                            Category                     Advertiser  \
# 0      CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 4      CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 7      CELLULAR PHONES-SMART PHONES                       MOTOROLA
# 9      CELLULAR PHONES-SMART PHONES  SAMSUNG INDIA ELECTRONICS LTD
# 12     CELLULAR PHONES-SMART PHONES                       MOTOROLA
# 15     CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 19     CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 21     CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 24     CELLULAR PHONES-SMART PHONES  SAMSUNG INDIA ELECTRONICS LTD
# 28     CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 60     CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 71     CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 75     CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 93     CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 107    CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 113    CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 118    CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 122    CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 124    CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 127    CELLULAR PHONES-SMART PHONES                     OPPO INDIA
# 128    CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 132    CELLULAR PHONES-SMART PHONES      VIVO MOBILE INDIA PVT LTD
# 138    CELLULAR PHONES-SMART PHONES                     OPPO INDIA
#
# 132       20362.83       200000  300000
# 138       16134.36       200000  300000
# 143       21341.97       200000  300000
# 144       22242.02       200000  600000
# 150       22293.36       200000  300000
# 168       16250.26       200000  600000
# 177       20515.11       200000  300000
# 180       20747.81       200000  600000
# 185       19188.05       200000  300000
# ...            ...          ...     ...
# 58719      9264.45       200000  300000
# 58725      9138.66       200000  400000
# 58730      8727.62       200000  300000
# 58734      9762.30       200000  400000
# 58753      7669.63       200000  400000
# 58758      8409.97       200000  300000
# 58762      8559.28       200000  300000
# 58764      8855.38       200000  300000
# 58766      8881.08       200000  400000
# 58770      8209.55       200000  300000
# 58778      8110.53       200000  400000
# 58781      8476.51       200000  600000
# 58782      8476.51       200000  300000
# 58784      8639.84       200000  300000
# 58788      9353.68       200000  400000
# 58797      7657.26       200000  200000
# 58801      8026.90       200000  300000
# 58803      8070.19       200000  300000
# 58810      8121.00       200000  400000
# 58820      5767.99       200000  600000
# 58824      5909.88       200000  400000
# 58826      7378.61       200000  300000
# 58832      7767.75       200000  300000
# 58836      7180.15       200000  300000
# 58843      7035.62       200000  300000
# 58849      7450.88       200000  300000
# 58862       327.09       200000  400000
# 58869       261.31       200000  900000
# 58909        91.89       200000  400000
# 58919        68.61       200000  400000
#
# [8967 rows x 15 columns]

# %% [markdown]
# ## Advertiser and Impressions

# %%
ipl_tel_grp = ipl_tel.groupby('Advertiser')
ipl_tel_grp_n = ipl_tel_grp["Impressions"].mean().sort_values(ascending=False)
ipl_tel_grp_n.plot(kind="bar")

# %% [markdown]
# ## Company Spends

# %%
ipl_tel_grp_p = ipl_tel_grp[["Cost", "Rate/10 Sec"]].mean().sort_values(by = "Cost").plot(title = 'Cost & Rate/10 Sec', kind = "bar")
ipl_tel_grp_p = ipl_tel_grp_p.get_figure()
ipl_tel_grp_p.set_size_inches(22, 12)

# %% [markdown]
# ## Advertisement Length

# %%
ipl_tel_grp_len = ipl_tel_grp[["Length [sec] {Av}"]].mean().sort_values(by = "Length [sec] {Av}")
ipl_tel_grp_len['Length Median'] = ipl_tel_grp[["Length [sec] {Av}"]].median()
ipl_tel_grp_len['Length Max'] = ipl_tel_grp[["Length [sec] {Av}"]].max()
ipl_tel_grp_len['Length Min'] = ipl_tel_grp[["Length [sec] {Av}"]].min()
ipl_tel_grp_len['Length Sum'] = ipl_tel_grp[["Length [sec] {Av}"]].sum()
ipl_tel_grp_len
# Out:
#                                Length [sec] {Av}  Length Median  Length Max  \
# Advertiser
# SAMSUNG INDIA ELECTRONICS LTD          14.609030             10          30
# OPPO INDIA                             14.735107             15          15
# MOTOROLA                               15.177033             15          30
# VIVO MOBILE INDIA PVT LTD              17.792014             15          45
# SYNTECH TECHNOLOGY PVT LTD             18.320000             15          35
# MICROMAX INFORMATICS LTD               19.928315             20          20
# APPLE COMPUTER INDIA                   29.886121             30          30
# RELIANCE JIO INFOCOMM LTD              30.588235             30          45
#
#                                Length Min  Length Sum
# Advertiser
# SAMSUNG INDIA ELECTRONICS LTD           5       15208
# OPPO INDIA                              2       39328
# MOTOROLA                                3        3172
# VIVO MOBILE INDIA PVT LTD               3       61934
# SYNTECH TECHNOLOGY PVT LTD              2       10534
# MICROMAX INFORMATICS LTD                5       11120
# APPLE COMPUTER INDIA                    3        8398
# RELIANCE JIO INFOCOMM LTD              30        4680

# %%
ipl_tel_grp_len['Length Sum'].sort_values()
# Out:
# Advertiser
# MOTOROLA                          3172
# RELIANCE JIO INFOCOMM LTD         4680
# APPLE COMPUTER INDIA              8398
# SYNTECH TECHNOLOGY PVT LTD       10534
# MICROMAX INFORMATICS LTD         11120
# SAMSUNG INDIA ELECTRONICS LTD    15208
# OPPO INDIA                       39328
# VIVO MOBILE INDIA PVT LTD        61934
# Name: Length Sum, dtype: int64

# %% [markdown]
# ## Moto | Rel (Length)

# %%
ipl_mot_rel = ipl_tel[(ipl_tel["Advertiser"] == "MOTOROLA") | (ipl_tel["Advertiser"] == "RELIANCE JIO INFOCOMM LTD")]

# %%
sns.boxplot(x = "Advertiser", y = "Length [sec] {Av}", data = ipl_mot_rel, palette = "Set2", )

# %% [markdown]
# ## Cost to Impressions

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
out = pd.cut(ipl_tel["Cost"], bins = [40000, 200000, 400000, 600000, 800000, 1000000])
sns.barplot(x = out, y = "Impressions", data = ipl_tel, ax = ax)

# %% [markdown]
# ## Length to Impressions

# %%
#Is length related to impressions?
ipl_tel = ipl_data[(ipl_data['Sector'] == 'Telecom Products')]
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
out = pd.cut(ipl_tel["Length [sec] {Av}"], bins = [2, 5, 15, 25, 35, 45])
sns.barplot(x = out, y = "Impressions", data = ipl_tel)

# %% [markdown]
# ## Impression and Cost for the 4th month

# %%
ipl_m4 = ipl_tel[(ipl_tel['Month'] == 4)]
plt.figure(figsize = (20,8))
plt.subplots_adjust(wspace = 0.1)
plt.subplot(1,2,1)
sns.barplot(x = "Advertiser", y = "Cost", data = ipl_m4)
plt.xticks(rotation = 90)
plt.subplot(1,2,2)
sns.barplot(x = "Advertiser", y = "Impressions", data = ipl_m4)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Impression and Cost for the 5th month

# %%
ipl_m4 = ipl_tel[(ipl_tel['Month'] == 5)]
plt.figure(figsize = (20,8))
plt.subplot(1,2,1)
sns.barplot(x = "Advertiser", y = "Cost", data = ipl_m4)
plt.xticks(rotation = 90)
plt.subplot(1,2,2)
sns.barplot(x = "Advertiser", y = "Impressions", data = ipl_m4)
plt.xticks(rotation = 90)
plt.show()
# Reliance came in the 5th month

# %%
def tel_ad(adv):    
    ipl_tel_ad = ipl_tel[ipl_tel['Advertiser'] == adv]
    return ipl_tel_ad['Description'].value_counts()

# %%
print(tel_ad("APPLE COMPUTER INDIA"))
# Out:
# APPLE IPHONE 7         163
# APPLE IPHONE 7 PLUS    118
# Name: Description, dtype: int64

# %%
labels = ['APPLE IPHONE 7', 'APPLE IPHONE 7 PLUS']
plt.pie(tel_ad("APPLE COMPUTER INDIA"), labels = labels, startangle=90)
plt.show()
