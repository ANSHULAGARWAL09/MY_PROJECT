# %%
import numpy as np
import pandas as  pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import Imputer
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('sata.xlsx',header=3)
data.head()
# Out:
#         PO       Date   Type           Contact   QTY  \
# 0  3000000 2016-01-04   Ebay   Jospeh Glassett   100
# 1      NaN        NaT    NaN               NaN   100
# 2  3000001 2016-01-04   Ebay       Pat Winters  1000
# 3  3000002 2016-01-04  Check       Matt Colker   447
# 4  3000003 2016-01-04   Visa  Arthur Greenberg   250
#
#                              Product  Status  Gross     FVF  PayPal Fee   \
# 0                       2/0-4 Type G    Open  3900.0 -153.0       -74.70
# 1                       4/0-4 Type G     NaN     NaN    NaN          NaN
# 2                         Sweetbriar    Open  1800.0 -162.0       -34.50
# 3  4/0-3 W/GRND Jacketed MC CABLE CU    Open  5837.0    0.0         0.00
# 4              2/3 NM-B Romex W/GRND    Open  1375.0    0.0       -30.55
#
#       ...          Unnamed: 21                          Email  Yes  \
# 0     ...                  NaN  rockymountainauto@netzero.com  NaN
# 1     ...                  NaN                            NaN  NaN
# ...

# %%
data.isnull().sum()
# Out:
# PO                1626
# Date              1625
# Type              1626
# Contact           1625
# QTY                  7
# Product              3
#  Status           1626
# Gross             1624
#  FVF              1596
# PayPal Fee        1595
# Net               1584
# Cost/M             795
# Freight           1707
# Extended            23
# Profits            181
# Supplier            42
# %                 7461
# Unnamed: 17       7240
# Unnamed: 18       7235
# Carrier           1289
# Tracing Number    1246
# Unnamed: 21       5978
# Email             5841
# Yes               7457
# Unnamed: 24       7459
# Unnamed: 25       7461
# Unnamed: 26       7094
# Unnamed: 27       7460
# Unnamed: 28       7461
# Unnamed: 29       7461
# Unnamed: 30       7458
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461 entries, 0 to 7460
# Data columns (total 31 columns):
# PO                5835 non-null object
# Date              5836 non-null datetime64[ns]
# Type              5835 non-null object
# Contact           5836 non-null object
# QTY               7454 non-null object
# Product           7458 non-null object
#  Status           5835 non-null object
# Gross             5837 non-null float64
#  FVF              5865 non-null float64
# PayPal Fee        5866 non-null float64
# Net               5877 non-null float64
# Cost/M            6666 non-null object
# Freight           5754 non-null object
# Extended          7438 non-null float64
# Profits           7280 non-null float64
# Supplier          7419 non-null object
# %                 0 non-null float64
# Unnamed: 17       221 non-null object
# Unnamed: 18       226 non-null object
# Carrier           6172 non-null object
# Tracing Number    6215 non-null object
# ...

# %%
data = data.rename(columns = {'%':'percent' , 'Cost/M ':'CostM '})

# %%
data.drop(['percent','Unnamed: 24','Unnamed: 25','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30'] , axis=1 , inplace=True)

# %%
data
# Out:
#             PO       Date        Type              Contact   QTY  \
# 0      3000000 2016-01-04        Ebay      Jospeh Glassett   100
# 1          NaN        NaT         NaN                  NaN   100
# 2      3000001 2016-01-04        Ebay          Pat Winters  1000
# 3      3000002 2016-01-04       Check          Matt Colker   447
# 4      3000003 2016-01-04        Visa     Arthur Greenberg   250
# 5      3000004 2016-01-04        Visa       Joseph Baldwin  2500
# 6      3000005 2016-01-04        Visa       Daniel Echarri  8000
# 7      3000006 2016-01-04      PayPal           Alex Hruby  5000
# 8          NaN        NaT         NaN                  NaN  8000
# 9          NaN        NaT         NaN                  NaN   500
# 10         NaN        NaT         NaN                  NaN   500
# 11         NaN        NaT         NaN                  NaN   140
# 12    30000007 2016-01-04       Check      Tucker Electric   195
# ...

# %%
data['QTY'].value_counts(dropna=False)
# Out:
# 100      1136
# 250       846
# 500       749
# 50        569
# 1000      521
# 200       387
# 150       342
# 300       189
# 125       145
# 2000      134
# 75        109
# 175       104
# 25         85
# 400        80
# 225        68
# 1500       63
# 350        54
# 3000       53
# 5000       52
# 750        50
# 6          46
# 15         43
# 600        40
# 60         39
# 275        39
# 140        34
# 2500       32
# 10000      31
# 4000       29
# 450        28
#          ...
# 132         1
# 1304        1
# 5100        1
# 381         1
# 5781        1
# 5350        1
# 2148        1
# 3757        1
# 2695        1
# 315         1
# 2378        1
# 2365        1
# 1342        1
# 404         1
# 493         1
# 76          1
# 326         1
# 327         1
# 690         1
# 7856        1
# 343         1
# 1356        1
# 268         1
# 2382        1
# 1359        1
# 1360        1
# 11287       1
# 7634        1
# 77          1
# 412         1
# ...

# %%
data['Profits'].value_counts(dropna=False)
# Out:
#  0.00000       189
# NaN            181
# -40.00000       16
# -37.70000       10
# -75.00000        9
# -0.30000         9
# -60.00000        9
# -55.00000        8
# -37.50000        7
# -27.50000        7
# -30.00000        6
# -334.90000       6
# -806.55000       6
# -200.00000       6
# -525.00000       5
# -330.50000       5
# -710.00000       5
# -32.25000        5
# -150.00000       5
#  82.97128        5
# -330.00000       5
# -255.00000       4
#  275.28000       4
# -75.40000        4
# -300.00000       4
# -42.00000        4
# -825.00000       4
# -600.00000       4
# -33.00000        4
#  72.80000        4
#               ...
#  277.92000       1
#  73.98000        1
#  101.97774       1
# -2037.25000      1
#  47.37166        1
# -1466.10000      1
#  43.79312        1
#  33.69168        1
#  16.97750        1
# -62.79500        1
#  148.18000       1
#  49.45500        1
#  2252.45000      1
# -70.88800        1
#  38.30500        1
#  125.45430       1
# ...

# %%
data.QTY = data.QTY.ffill().bfill()

# %%
data.Profits = data.Profits.fillna(data.Profits.mean())

# %%
data
# Out:
#             PO       Date        Type              Contact   QTY  \
# 0      3000000 2016-01-04        Ebay      Jospeh Glassett   100
# 1          NaN        NaT         NaN                  NaN   100
# 2      3000001 2016-01-04        Ebay          Pat Winters  1000
# 3      3000002 2016-01-04       Check          Matt Colker   447
# 4      3000003 2016-01-04        Visa     Arthur Greenberg   250
# 5      3000004 2016-01-04        Visa       Joseph Baldwin  2500
# 6      3000005 2016-01-04        Visa       Daniel Echarri  8000
# 7      3000006 2016-01-04      PayPal           Alex Hruby  5000
# 8          NaN        NaT         NaN                  NaN  8000
# 9          NaN        NaT         NaN                  NaN   500
# 10         NaN        NaT         NaN                  NaN   500
# 11         NaN        NaT         NaN                  NaN   140
# 12    30000007 2016-01-04       Check      Tucker Electric   195
# ...

# %%
pd.crosstab(data.PO , data.QTY)
# Out:
# QTY       0      1      2      3      4      5      6      9      10     \
# PO
# 3             0      0      0      0      0      0      0      0      0
# 3000000       0      0      0      0      0      0      0      0      0
# 3000001       0      0      0      0      0      0      0      0      0
# 3000002       0      0      0      0      0      0      0      0      0
# 3000003       0      0      0      0      0      0      0      0      0
# 3000004       0      0      0      0      0      0      0      0      0
# 3000005       0      0      0      0      0      0      0      0      0
# 3000006       0      0      0      0      0      0      0      0      0
# 3000008       0      0      0      0      0      0      0      0      0
# 3000009       0      0      0      0      0      0      0      0      0
# 3000010       0      0      0      0      0      0      0      0      0
# 3000011       0      0      0      0      0      0      0      0      1
# ...

# %%
#plt.bar(data.PO , data.Profits)
#plt.xlabel('PO')
#plt.ylabel('Profit')
#plt.title('Max Profit')
#plt.legend()
#plt.show()

# %%
#data = data[(data['PO'] >= 30) & (data['PO'] <= 38)]
type(data.QTY[0])
# Out:
# int

# %%
data.QTY.value_counts()
# Out:
# 100      1136
# 250       847
# 500       749
# 50        569
# 1000      521
# 200       387
# 150       342
# 300       190
# 125       145
# 2000      134
# 75        109
# 175       104
# 25         85
# 400        80
# 225        68
# 1500       63
# 350        54
# 3000       53
# 5000       52
# 750        50
# 6          47
# 15         43
# 600        40
# 60         39
# 275        39
# 140        34
# 2500       32
# 10000      31
# 4000       29
# 450        28
#          ...
# 1304        1
# 670         1
# 381         1
# 5100        1
# 5781        1
# 5350        1
# 386         1
# 4422        1
# 347         1
# 2365        1
# 690         1
# 1342        1
# 702         1
# 493         1
# 404         1
# 326         1
# 327         1
# 76          1
# 2378        1
# 1356        1
# 2695        1
# 268         1
# 2382        1
# 1359        1
# 1360        1
# 11287       1
# 7634        1
# 7856        1
# 343         1
# 825         1
# ...

# %%
for i in range(len(data.PO)):
    if(type(data.QTY[i]) != int):
        print(data.QTY[i])
        #int(data.PO[i])
        del data.QTY[i]
# Out:
# SAMPLE

# %%
data
# Out:
#             PO       Date        Type              Contact   QTY  \
# 0      3000000 2016-01-04        Ebay      Jospeh Glassett   100
# 1          NaN        NaT         NaN                  NaN   100
# 2      3000001 2016-01-04        Ebay          Pat Winters  1000
# 3      3000002 2016-01-04       Check          Matt Colker   447
# 4      3000003 2016-01-04        Visa     Arthur Greenberg   250
# 5      3000004 2016-01-04        Visa       Joseph Baldwin  2500
# 6      3000005 2016-01-04        Visa       Daniel Echarri  8000
# 7      3000006 2016-01-04      PayPal           Alex Hruby  5000
# 8          NaN        NaT         NaN                  NaN  8000
# 9          NaN        NaT         NaN                  NaN   500
# 10         NaN        NaT         NaN                  NaN   500
# 11         NaN        NaT         NaN                  NaN   140
# 12    30000007 2016-01-04       Check      Tucker Electric   195
# ...

# %%
##plt.bar(data.PO , data.Profits)
##plt.xlabel('PO')
##plt.ylabel('Profit')
##plt.title('Max Profit')
##plt.legend()
##plt.show

# %%
data.QTY.shape
# Out:
# (7460,)

# %%
data.Profits.shape
# Out:
# (7461,)
